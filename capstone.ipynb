# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = {
    'Quarter': ['2023/12', '2023/9', '2023/6', '2023/3', '2022/12', '2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3', '2020/12', '2020/9', '2020/6', '2020/3', '2019/12', '2019/9', '2019/6', '2019/3', '2018/12', '2018/9', '2018/6', '2018/3', '2017/12', '2017/9', '2017/6', '2017/3', '2016/12', '2016/9', '2016/6', '2016/3', '2015/12', '2015/9', '2015/6', '2015/3', '2014/12', '2014/9', '2014/6', '2014/3', '2013/12', '2013/9', '2013/6', '2013/3', '2012/12', '2012/9', '2012/6', '2012/3', '2011/12', '2011/9', '2011/6', '2011/3', '2010/12', '2010/9', '2010/6', '2010/3', '2009/12', '2009/9', '2009/6', '2009/3', '2008/12', '2008/9', '2008/6', '2008/3'],
    'Sales': ['$2.695.226.908,99', '$2.079.481.375,94', '$1.568.078.700,32', '$927.678.211,57', '$3.323.153.624,72', '$2.468.921.409,73', '$1.523.451.541,23', '$823.539.818,88', '$2.310.007.786,72', '$1.891.734.304,48', '$985.681.157,12', '$485.194.919,62', '$1.477.684.832,54', '$1.156.832.657,99', '$810.527.818,54', '$468.853.023,95', '$1.855.243.555,60', '$1.428.666.617,73', '$964.247.453,96', '$553.069.479,97', '$2.523.076.817,95', '$1.689.742.641,23', '$1.162.868.270,42', '$550.243.433,69', '$2.784.162.354,60', '$2.253.398.083,56', '$1.383.022.685,54', '$662.388.478,54', '$3.228.155.590,42', '$2.677.983.655,29', '$1.858.140.814,22', '$903.453.439,41', '$4.261.106.982,26', '$3.299.676.987,79', '$2.366.757.516,49', '$1.280.275.489,81', '$5.628.905.871,37', '$4.369.085.315,39', '$3.003.171.645,67', '$1.458.228.057,02', '$6.066.695.468,98', '$4.629.489.615,06', '$3.232.087.088,18', '$1.569.939.699,25', '$5.765.401.746,83', '$3.939.922.361,77', '$2.465.704.797,41', '$1.121.720.573,32', '$4.595.480.172,25', '$3.410.425.773,20', '$2.342.986.617,69', '$1.126.726.087,07', '$4.727.206.160,41', '$3.504.549.454,64', '$2.333.072.474,52', '$1.083.172.162,03', '$5.347.693.306,80', '$4.088.515.638,73', '$2.754.177.435,63', '$1.420.087.637,16', '$5.884.977.973,62', '$5.366.392.619,57', '$3.247.519.838,59', '$1.641.542.991,68']
}

df = pd.DataFrame(data)

# %%
df['Quarter'] = pd.to_datetime(df['Quarter'])
# Out:
# /tmp/ipykernel_562/4090791732.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Quarter'] = pd.to_datetime(df['Quarter'])

# %%
df.head()
# Out:
#      Quarter              Sales
# 0 2023-12-01  $2.695.226.908,99
# 1 2023-09-01  $2.079.481.375,94
# 2 2023-06-01  $1.568.078.700,32
# 3 2023-03-01    $927.678.211,57
# 4 2022-12-01  $3.323.153.624,72

# %%
import re
df['Sales'] = [re.sub(r'\$', '', s) for s in df['Sales']]

# %%
df.head()
# Out:
#      Quarter             Sales
# 0 2023-12-01  2.695.226.908,99
# 1 2023-09-01  2.079.481.375,94
# 2 2023-06-01  1.568.078.700,32
# 3 2023-03-01    927.678.211,57
# 4 2022-12-01  3.323.153.624,72

# %%
df['Sales'] = [s.replace('.', '') for s in df['Sales']]

# %%
df.head()
# Out:
#      Quarter          Sales
# 0 2023-12-01  2695226908,99
# 1 2023-09-01  2079481375,94
# 2 2023-06-01  1568078700,32
# 3 2023-03-01   927678211,57
# 4 2022-12-01  3323153624,72

# %%
df['Sales'] = [s.replace(',', '.') for s in df['Sales']]

# Convert 'Sales' column to float
df['Sales'] = df['Sales'].astype(float)

# %%
df.head()
# Out:
#      Quarter         Sales
# 0 2023-12-01  2.695227e+09
# 1 2023-09-01  2.079481e+09
# 2 2023-06-01  1.568079e+09
# 3 2023-03-01  9.276782e+08
# 4 2022-12-01  3.323154e+09

# %%
df['Sales'][0]
# Out:
# 2695226908.99

# %%
df = df.sort_values(by='Quarter', ascending=True).reset_index(drop=True)

print(df)
# Out:
#       Quarter         Sales
# 0  2008-03-01  1.641543e+09
# 1  2008-06-01  3.247520e+09
# 2  2008-09-01  5.366393e+09
# 3  2008-12-01  5.884978e+09
# 4  2009-03-01  1.420088e+09
# ..        ...           ...
# 59 2022-12-01  3.323154e+09
# 60 2023-03-01  9.276782e+08
# 61 2023-06-01  1.568079e+09
# 62 2023-09-01  2.079481e+09
# 63 2023-12-01  2.695227e+09
#
# [64 rows x 2 columns]

# %%
df.head()
# Out:
#      Quarter         Sales
# 0 2008-03-01  1.641543e+09
# 1 2008-06-01  3.247520e+09
# 2 2008-09-01  5.366393e+09
# 3 2008-12-01  5.884978e+09
# 4 2009-03-01  1.420088e+09

# %%
earthquake_data = {
    'Date': ['2011-11-09', '2020-01-24', '2020-10-30', '2023-03-06'],  # Replace 'xxxx-xx-xx' with Kahramanmaraş earthquake date
    'Magnitude': [5.6, 6.8, 6.6, 7.7],  # Magnitude of earthquakes
    'Location': ['Van', 'Sivrice (Elaziğ)', 'Seferihisar (Izmir)', 'Kahramanmaraş']  # Location of earthquakes
}

# %%
earthquake_df = pd.DataFrame(earthquake_data)
earthquake_df['Date'] = pd.to_datetime(earthquake_df['Date'])

# %%
df['Quarter'] = pd.to_datetime(df['Quarter'])

# %%
merged_df = pd.merge(df, earthquake_df, left_on='Quarter', right_on='Date', how='left')

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['Quarter'], df['Sales'], marker='o', label='Sales')
for idx, row in earthquake_df.iterrows():
    plt.scatter(row['Date'], df.loc[df['Quarter'] <= row['Date'], 'Sales'].iloc[-1], color='red', label=row['Location'] + ' Earthquake')
plt.title('Sales Over Time with Earthquake Occurrences')
plt.xlabel('Quarter')
plt.ylabel('Sales')
plt.legend()
plt.grid(True)
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller

# %%
# Plot the time series
plt.figure(figsize=(10, 6))
plt.plot(df.index, df['Sales'], marker='o')
plt.title('Sales Over Time')
plt.xlabel('Quarter')
plt.ylabel('Sales')
plt.grid(True)
plt.show()

# %%
df['Quarter'] = pd.to_datetime(df['Quarter'])
df.set_index('Quarter', inplace=True)

# %%
def check_stationarity(data):
    result = adfuller(data)
    print('ADF Statistic:', result[0])
    print('p-value:', result[1])
    print('Critical Values:')
    for key, value in result[4].items():
        print('\t{}: {}'.format(key, value))

check_stationarity(df['Sales'])

# Decompose the time series
decomposition = seasonal_decompose(df['Sales'], model='additive')
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid
# Out:
# ADF Statistic: -1.5077207226440474
# p-value: 0.529688609059576
# Critical Values:
# 	1%: -3.5463945337644063
# 	5%: -2.911939409384601
# 	10%: -2.5936515282964665

# %%
plt.figure(figsize=(10, 8))

plt.subplot(411)
plt.plot(df['Sales'], label='Original', color='blue')
plt.legend(loc='best')

plt.subplot(412)
plt.plot(trend, label='Trend', color='blue')
plt.legend(loc='best')

plt.subplot(413)
plt.plot(seasonal, label='Seasonality', color='blue')
plt.legend(loc='best')

plt.subplot(414)
plt.plot(residual, label='Residuals', color='blue')
plt.legend(loc='best')

plt.tight_layout()
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_pacf
plot_pacf(df.Sales.diff().dropna())

# %%
from statsmodels.graphics.tsaplots import plot_acf

plot_acf(df.Sales.diff().dropna())

# %%
from pmdarima.arima import auto_arima

model = auto_arima(df['Sales'], start_p=1, start_q=1,
                      test='adf',
                      max_p=5, max_q=5,
                      m=1,             
                      d=1,          
                      seasonal=False,   
                      start_P=0, 
                      D=None, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=3272.957, Time=0.06 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=2870.490, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=2867.418, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=2863.292, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=2868.503, Time=0.01 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=2847.966, Time=0.04 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=2847.206, Time=0.05 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=2822.084, Time=0.07 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=3119.543, Time=0.03 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.13 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=2825.662, Time=0.07 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=2831.383, Time=0.05 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=2835.609, Time=0.08 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.21 sec
# ...

# %%
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(df['Sales'], order=(2,1,2))
fit_model = model.fit()

# Forecast
forecast = fit_model.forecast(steps=4)  # Forecasting for 4 quarters in 2024

# Print forecasted values
print("Forecasted Sales for 2024 Quarters:")
print(forecast)
# Out:
# Forecasted Sales for 2024 Quarters:
# 2024-03-01    1.832961e+09
# 2024-06-01    1.054967e+09
# 2024-09-01    1.649177e+09
# 2024-12-01    2.377786e+09
# Freq: QS-DEC, Name: predicted_mean, dtype: float64
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency QS-DEC will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency QS-DEC will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency QS-DEC will be used.
#   self._init_dates(dates, freq)

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Forecasted Sales for 2024 Quarters
forecasted_sales_data = {
    'Quarter': ['2024-03-01', '2024-06-01', '2024-09-01', '2024-12-01'],
    'Sales': [1.832961e+09, 1.054967e+09, 1.649177e+09, 2.377786e+09]
}

forecasted_sales_df = pd.DataFrame(forecasted_sales_data)
forecasted_sales_df['Quarter'] = pd.to_datetime(forecasted_sales_df['Quarter'])

# Plot sales data and forecasted sales
plt.figure(figsize=(10, 6))
plt.plot(df['Quarter'], df['Sales'], marker='o', label='Historical Sales')
plt.plot(forecasted_sales_df['Quarter'], forecasted_sales_df['Sales'], marker='o', linestyle='dashed', color='green', label='Forecasted Sales')
plt.title('Sales Over Time with Forecasted Sales for 2024 Quarters')
plt.xlabel('Quarter')
plt.ylabel('Sales')
plt.legend()
plt.grid(True)
plt.show()
